# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_zh.geojson"
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature      1            1004              1040           1271
# 1  Feature     10            1004              1020           1110
# 2  Feature    100            1004              1020           1110
# 3  Feature   1000            1007              1030           1110
# 4  Feature  10000            1004              1030           1121
#
#    municipalityNumber    municipalityName canton   type  \
# 0                   2  Affoltern am Albis     ZH  Point
# 1                   2  Affoltern am Albis     ZH  Point
# 2                   2  Affoltern am Albis     ZH  Point
# 3                   2  Affoltern am Albis     ZH  Point
# 4                 291         Andelfingen     ZH  Point
#
#                   coordinates
# 0          [2676523, 1235843]
# 1  [2676440.038, 1235973.538]
# 2  [2676765.706, 1236101.658]
# 3  [2676644.881, 1236812.863]
# 4   [2693391.65, 1272255.267]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 393248  Feature  99995            1004              1040              0
# 393249  Feature  99996            1004              1040              0
# 393250  Feature  99997            1004              1040              0
# 393251  Feature  99998            1004              1040              0
# 393252  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 393248                 198               Uster     ZH  Point  2696792.976
# 393249                 198               Uster     ZH  Point  2696718.474
# 393250                 198               Uster     ZH  Point  2696722.040
# 393251                 198               Uster     ZH  Point  2696727.666
# 393252                 198               Uster     ZH  Point  2696710.888
#
#            y_coords
# 0       1235843.000
# 1       1235973.538
# 2       1236101.658
# 3       1236812.863
# 4       1272255.267
# ...             ...
# 393248  1245085.637
# 393249  1245039.536
# 393250  1245043.472
# 393251  1245050.586
# 393252  1245059.793
#
# [393253 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 393248  Feature  99995            1004              1040              0
# 393249  Feature  99996            1004              1040              0
# 393250  Feature  99997            1004              1040              0
# 393251  Feature  99998            1004              1040              0
# 393252  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 393248                 198               Uster     ZH  Point  2696792.976
# 393249                 198               Uster     ZH  Point  2696718.474
# 393250                 198               Uster     ZH  Point  2696722.040
# 393251                 198               Uster     ZH  Point  2696727.666
# 393252                 198               Uster     ZH  Point  2696710.888
#
#            y_coords   latitude  longitude
# 0       1235843.000  47.269056   8.449859
# 1       1235973.538  47.270239   8.448785
# 2       1236101.658  47.271354   8.453110
# 3       1236812.863  47.277764   8.451635
# 4       1272255.267  47.594339   8.680355
# ...             ...        ...        ...
# 393248  1245085.637  47.349516   8.719673
# 393249  1245039.536  47.349113   8.718677
# 393250  1245043.472  47.349147   8.718725
# 393251  1245050.586  47.349211   8.718801
# 393252  1245059.793  47.349296   8.718581
#
# [393253 rows x 13 columns]

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df.loc[df['municipalityName'] == 'Greifensee'].sample(100).dropna()
df_sub

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingCategory']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6083155da2fbb80dc69e4e4e246260a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6083155da2fbb80dc69e4e4e246260a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6083155da2fbb80dc69e4e4e246260a = L.map(
#                 &quot;map_d6083155da2fbb80dc69e4e4e246260a&quot;,
#                 {
#                     center: [47.36680872756793, 8.681076764354192],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a7ebf66f136afacb2f673b46fc432ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a7ebf66f136afacb2f673b46fc432ed.addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#             var marker_60de8c8f26a07edad09918682ebf5512 = L.marker(
#                 [47.37086444778093, 8.676492245645068],
#                 {}
#             ).addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#         var popup_ef1abd2bd03ebaf88d8fb31ef297716b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31ec38a7d31be300bf43abd9d02be2f2 = $(`&lt;div id=&quot;html_31ec38a7d31be300bf43abd9d02be2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_ef1abd2bd03ebaf88d8fb31ef297716b.setContent(html_31ec38a7d31be300bf43abd9d02be2f2);
#
#
#
#         marker_60de8c8f26a07edad09918682ebf5512.bindPopup(popup_ef1abd2bd03ebaf88d8fb31ef297716b)
#         ;
#
#
#
#
#             var marker_67b41a706f65eb156780b12fbf8c7445 = L.marker(
#                 [47.36919371383578, 8.67896996558678],
#                 {}
#             ).addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#         var popup_836607cce121e76f4c2bfae65ff292bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d3fb77ea12b06746baaaae323f391fc = $(`&lt;div id=&quot;html_2d3fb77ea12b06746baaaae323f391fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_836607cce121e76f4c2bfae65ff292bc.setContent(html_2d3fb77ea12b06746baaaae323f391fc);
#
#
#
#         marker_67b41a706f65eb156780b12fbf8c7445.bindPopup(popup_836607cce121e76f4c2bfae65ff292bc)
#         ;
#
#
#
#
#             var marker_11731a43a3e0ee2678b71226b4d042b0 = L.marker(
#                 [47.37207292208051, 8.677043646438184],
#                 {}
#             ).addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#         var popup_3161e5238ce5412d3076e0bc1f144fc9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_641724d7c17db8e193f7c3ab5f4cf867 = $(`&lt;div id=&quot;html_641724d7c17db8e193f7c3ab5f4cf867&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_3161e5238ce5412d3076e0bc1f144fc9.setContent(html_641724d7c17db8e193f7c3ab5f4cf867);
#
#
#
#         marker_11731a43a3e0ee2678b71226b4d042b0.bindPopup(popup_3161e5238ce5412d3076e0bc1f144fc9)
#         ;
#
#
#
#
#             var marker_8fe41985b8e8355a19df05185ad4ad4b = L.marker(
#                 [47.36462630128305, 8.67938517691675],
#                 {}
#             ).addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#         var popup_9e97971d5fc53fa786a6a87d657322a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b884ee1a1c318fe577a4b1335d18c026 = $(`&lt;div id=&quot;html_b884ee1a1c318fe577a4b1335d18c026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1080&lt;/div&gt;`)[0];
#                 popup_9e97971d5fc53fa786a6a87d657322a5.setContent(html_b884ee1a1c318fe577a4b1335d18c026);
#
#
#
#         marker_8fe41985b8e8355a19df05185ad4ad4b.bindPopup(popup_9e97971d5fc53fa786a6a87d657322a5)
#         ;
#
#
#
#
#             var marker_4fdc2af7ffb755c8c61d436da1c9d2e4 = L.marker(
#                 [47.36354456311173, 8.689162196918474],
#                 {}
#             ).addTo(map_d6083155da2fbb80dc69e4e4e246260a);
#
#
#         var popup_d4ec762fc0ef3f7085fdfdaeda07fd99 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e7d605c8902843c2d4519dc1d177b0f = $(`&lt;div id=&quot;html_4e7d605c8902843c2d4519dc1d177b0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_d4ec762fc0ef3f7085fdfdaeda07fd99.setContent(html_4e7d605c8902843c2d4519dc1d177b0f);
#
#
#
#         marker_4fdc2af7ffb755c8c61d436da1c9d2e4.bindPopup(popup_d4ec762fc0ef3f7085fdfdaeda07fd99)
#         ;
#
#
#
#
#             var marker_1b10844936922a26d29b5c1f25d6b4fb = L.marker(
#                 [47.36948605721061, 8.679018345108123],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1019-azure
# Datetime: 2024-03-12 10:25:35
# Python Version: 3.10.13
# -----------------------------------
